# %% [markdown]
# <a href="https://colab.research.google.com/github/20104047TranThiMyNgoc/AI-Subject/blob/main/15_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN

# %%
url="/content/SM.jpg"
pixels=plt.imread(url)

# %%
detector=MTCNN()
faces=detector.detect_faces(pixels)
# Out:
# ...
# 8/8 [==============================] - 0s 4ms/step

# %%
for face in faces:
  print(face)
# Out:
# {'box': [95, 171, 66, 85], 'confidence': 0.9999986886978149, 'keypoints': {'left_eye': (117, 203), 'right_eye': (146, 216), 'nose': (124, 229), 'mouth_left': (105, 229), 'mouth_right': (133, 242)}}
# {'box': [1002, 16, 82, 111], 'confidence': 0.9999942779541016, 'keypoints': {'left_eye': (1035, 58), 'right_eye': (1072, 65), 'nose': (1055, 89), 'mouth_left': (1029, 96), 'mouth_right': (1064, 103)}}
# {'box': [584, 23, 60, 81], 'confidence': 0.9999909400939941, 'keypoints': {'left_eye': (602, 55), 'right_eye': (629, 60), 'nose': (613, 72), 'mouth_left': (598, 83), 'mouth_right': (622, 88)}}
# {'box': [52, 492, 48, 58], 'confidence': 0.99998939037323, 'keypoints': {'left_eye': (61, 518), 'right_eye': (82, 512), 'nose': (71, 526), 'mouth_left': (69, 540), 'mouth_right': (84, 535)}}
# {'box': [330, 496, 44, 52], 'confidence': 0.9999874830245972, 'keypoints': {'left_eye': (340, 518), 'right_eye': (360, 511), 'nose': (353, 525), 'mouth_left': (350, 538), 'mouth_right': (364, 534)}}
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
url="/content/SM.jpg"
pixels=plt.imread(url)
detector=MTCNN()
faces=detector.detect_faces(pixels)
plt.imshow(pixels)
# Out:
# ...
# 8/8 [==============================] - 0s 3ms/step

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
url='/content/Idol gruplarının yaş ortaşlamaları.jpg'
pixels=plt.imread(url)
detector=MTCNN()
faces=detector.detect_faces(pixels)
plt.imshow(pixels)
ax=plt.gca()
for face in faces:
  x,y,width,height=face['box']
  rect=plt.Rectangle((x,y),width,height,fill=False,color='red')
  ax.add_patch(rect)
plt.show()
# Out:
# ...
# 20/20 [==============================] - 0s 3ms/step

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
url='/content/bo-anh-ky-yeu-moc-mac-bat-ngo-hot-vi-co-tho-chup-anh-dac-biet.jpg'
pixels=plt.imread(url)
detector=MTCNN()
faces=detector.detect_faces(pixels)
plt.imshow(pixels)
ax=plt.gca()
for face in faces:
  x,y,width,height=face['box']
  rect=plt.Rectangle((x,y),width,height,fill=False,color='red')
  ax.add_patch(rect)
  for key,value in face['keypoints'].items():
    dot=plt.Circle(value,radius=2,color='red')
    ax.add_patch(dot)
plt.show()
# Out:
# ...
# 5/5 [==============================] - 0s 4ms/step

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
def draw_faces(filename, result_list):
  data = plt.imread(filename)
  for i in range(len(result_list)):
    x1,y1,width, height = result_list[i]['box']
    x2,y2 = x1 + width, y1 + height
    plt.subplot(1,len(result_list),i+1)
    plt.axis('off')
    plt.imshow(data[y1:y2,x1:x2])
  plt.show( )
filename = '/content/SM.jpg'
pixels = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(pixels)
draw_faces(filename, faces)
# Out:
# ...
# 8/8 [==============================] - 0s 3ms/step

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')

img_path = '/content/con-heo-mo-hinh-trang-tri.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357)
# Out:
# 1/1 [==============================] - 1s 787ms/step
# Predicted: [('n02395406', 'hog', 0.39757958), ('n02441942', 'weasel', 0.09194673), ('n01632777', 'axolotl', 0.086203724)]

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input
import numpy as np
model = VGG16(weights='imagenet', include_top=False)
img_path ='/content/cánh cụt.png'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

features = model.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 [==============================] - 0s 104ms/step
# Predicted: [('n02395406', 'hog', 0.39757958), ('n02441942', 'weasel', 0.09194673), ('n01632777', 'axolotl', 0.086203724)]
