# %% [markdown]
# <a href="https://colab.research.google.com/github/20104047TranThiMyNgoc/AI-Subject/blob/main/rice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from sklearn.utils import validation
from keras.preprocessing.image import ImageDataGenerator
from sklearn import preprocessing
from keras.utils import to_categorical
from keras.models import load_model
from keras.utils import load_img, img_to_array
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/BT/nhan dien gao
# Out:
# /content/drive/.shortcut-targets-by-id/1RhyDbz8sumcr_A27lkVwoL4keJgaMkNr/Colab Notebooks/BT/nhan dien gao

# %%
train_data = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
train_set = train_data.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/BT/nhan dien gao/Train',target_size=(300,300), batch_size=32, class_mode='categorical')
# Out:
# Found 354 images belonging to 18 classes.

# %%
test_set = train_data.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/BT/nhan dien gao/Test',target_size=(300,300), batch_size=32, class_mode='categorical')
# Out:
# Found 190 images belonging to 18 classes.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_set.class_indices
# Out:
# {'gao 4900': 0,
#  'gao 504': 1,
#  'gao 5451': 2,
#  'gao 6976': 3,
#  'gao ST21': 4,
#  'gao ST25': 5,
#  'gao bac huong': 6,
#  'gao den': 7,
#  'gao ham chau': 8,
#  'gao lut': 9,
#  'gao nang hoa': 10,
#  'gao nang sen': 11,
#  'gao nep': 12,
#  'gao tai nguyen': 13,
#  'gao thom': 14,
#  'gao thom lai': 15,
#  'gao tim than': 16,
#  'gao vang': 17}

# %%
test_set.class_indices
# Out:
# {'gao 4900': 0,
#  'gao 504': 1,
#  'gao 5451': 2,
#  'gao 6976': 3,
#  'gao ST21': 4,
#  'gao ST25': 5,
#  'gao bac huong': 6,
#  'gao den': 7,
#  'gao ham chau': 8,
#  'gao lut': 9,
#  'gao nang hoa': 10,
#  'gao nang sen': 11,
#  'gao nep': 12,
#  'gao tai nguyen': 13,
#  'gao thom': 14,
#  'gao thom lai': 15,
#  'gao tim than': 16,
#  'gao vang': 17}

# %%
model=Sequential()
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(300,300,3))) 
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(300,300,3))) 
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(300,300,3))) 
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
model.add(Dense(18,activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 300, 300, 32)      896
#
#  conv2d_7 (Conv2D)           (None, 300, 300, 32)      9248
#
#  max_pooling2d_3 (MaxPooling  (None, 150, 150, 32)     0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 150, 150, 64)      18496
#
#  conv2d_9 (Conv2D)           (None, 150, 150, 64)      36928
#
#  max_pooling2d_4 (MaxPooling  (None, 75, 75, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 75, 75, 128)       73856
#
#  conv2d_11 (Conv2D)          (None, 75, 75, 128)       147584
#
#  max_pooling2d_5 (MaxPooling  (None, 37, 37, 128)      0
#  2D)
#
#  flatten_1 (Flatten)         (None, 175232)            0
#
#  dense_2 (Dense)             (None, 128)               22429824
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 18)                2322
#
# =================================================================
# Total params: 22,719,154
# Trainable params: 22,719,154
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Biên dịch 
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(train_set,epochs=100,batch_size=128,verbose=1, validation_data=test_set, callbacks=[EarlyStopping(monitor='val_loss', patience=20)])
# Out:
# Epoch 1/100
# 12/12 [==============================] - 354s 29s/step - loss: 17.5435 - accuracy: 0.0508 - val_loss: 2.8840 - val_accuracy: 0.0632
# Epoch 2/100
# 12/12 [==============================] - 16s 1s/step - loss: 2.8793 - accuracy: 0.0819 - val_loss: 2.8783 - val_accuracy: 0.0632
# Epoch 3/100
# 12/12 [==============================] - 16s 1s/step - loss: 2.8933 - accuracy: 0.0706 - val_loss: 2.8809 - val_accuracy: 0.1053
# Epoch 4/100
# 12/12 [==============================] - 17s 1s/step - loss: 2.8726 - accuracy: 0.0876 - val_loss: 2.8412 - val_accuracy: 0.0789
# Epoch 5/100
# 12/12 [==============================] - 17s 1s/step - loss: 2.7826 - accuracy: 0.0989 - val_loss: 2.7528 - val_accuracy: 0.1000
# Epoch 6/100
# 12/12 [==============================] - 17s 1s/step - loss: 2.6516 - accuracy: 0.1525 - val_loss: 2.6967 - val_accuracy: 0.1632
# Epoch 7/100
# 12/12 [==============================] - 16s 1s/step - loss: 2.5200 - accuracy: 0.1836 - val_loss: 2.4098 - val_accuracy: 0.2684
# Epoch 8/100
# 12/12 [==============================] - 16s 1s/step - loss: 2.6530 - accuracy: 0.1582 - val_loss: 2.5998 - val_accuracy: 0.1158
# Epoch 9/100
# 12/12 [==============================] - 16s 1s/step - loss: 2.5062 - accuracy: 0.1921 - val_loss: 2.5509 - val_accuracy: 0.2263
# Epoch 10/100
# 12/12 [==============================] - 16s 1s/step - loss: 2.5107 - accuracy: 0.2316 - val_loss: 2.3375 - val_accuracy: 0.2632
# Epoch 11/100
# 12/12 [==============================] - 16s 1s/step - loss: 2.3856 - accuracy: 0.2429 - val_loss: 2.5133 - val_accuracy: 0.2895
# Epoch 12/100
# 12/12 [==============================] - 17s 1s/step - loss: 2.2852 - accuracy: 0.2966 - val_loss: 2.2172 - val_accuracy: 0.2895
# Epoch 13/100
# 12/12 [==============================] - 17s 1s/step - loss: 2.1477 - accuracy: 0.3136 - val_loss: 2.2617 - val_accuracy: 0.2789
# Epoch 14/100
# 12/12 [==============================] - 16s 1s/step - loss: 2.1476 - accuracy: 0.3107 - val_loss: 1.9971 - val_accuracy: 0.3526
# Epoch 15/100
# 12/12 [==============================] - 16s 1s/step - loss: 1.9397 - accuracy: 0.4237 - val_loss: 1.9101 - val_accuracy: 0.4263
# Epoch 16/100
# 12/12 [==============================] - 17s 1s/step - loss: 1.8201 - accuracy: 0.4435 - val_loss: 1.7717 - val_accuracy: 0.4632
# Epoch 17/100
# 12/12 [==============================] - 16s 1s/step - loss: 1.8542 - accuracy: 0.4153 - val_loss: 1.6460 - val_accuracy: 0.5211
# Epoch 18/100
# 12/12 [==============================] - 16s 1s/step - loss: 1.7232 - accuracy: 0.4802 - val_loss: 1.7497 - val_accuracy: 0.4737
# Epoch 19/100
# 12/12 [==============================] - 16s 1s/step - loss: 1.7236 - accuracy: 0.4689 - val_loss: 1.7211 - val_accuracy: 0.4684
# Epoch 20/100
# 12/12 [==============================] - 16s 1s/step - loss: 1.7236 - accuracy: 0.4972 - val_loss: 1.7650 - val_accuracy: 0.5105
# Epoch 21/100
# 12/12 [==============================] - 16s 1s/step - loss: 1.6474 - accuracy: 0.4802 - val_loss: 1.4476 - val_accuracy: 0.5316
# Epoch 22/100
# 12/12 [==============================] - 16s 1s/step - loss: 1.4336 - accuracy: 0.5508 - val_loss: 1.4960 - val_accuracy: 0.5263
# Epoch 23/100
# 12/12 [==============================] - 16s 1s/step - loss: 1.4893 - accuracy: 0.5169 - val_loss: 1.5070 - val_accuracy: 0.5526
# Epoch 24/100
# 12/12 [==============================] - 16s 1s/step - loss: 1.5914 - accuracy: 0.5113 - val_loss: 1.3457 - val_accuracy: 0.5737
# Epoch 25/100
# 12/12 [==============================] - 16s 1s/step - loss: 1.3789 - accuracy: 0.5678 - val_loss: 1.4748 - val_accuracy: 0.5684
# Epoch 26/100
# 12/12 [==============================] - 16s 1s/step - loss: 1.3018 - accuracy: 0.5932 - val_loss: 1.2829 - val_accuracy: 0.6211
# Epoch 27/100
# 12/12 [==============================] - 16s 1s/step - loss: 1.3623 - accuracy: 0.5876 - val_loss: 1.2482 - val_accuracy: 0.6316
# Epoch 28/100
# 12/12 [==============================] - 16s 1s/step - loss: 1.2874 - accuracy: 0.6073 - val_loss: 1.2602 - val_accuracy: 0.6211
# Epoch 29/100
# 12/12 [==============================] - 16s 1s/step - loss: 1.3687 - accuracy: 0.5706 - val_loss: 1.4183 - val_accuracy: 0.5842
# Epoch 30/100
# 12/12 [==============================] - 18s 2s/step - loss: 1.4148 - accuracy: 0.5734 - val_loss: 1.6761 - val_accuracy: 0.4947
# Epoch 31/100
# 12/12 [==============================] - 17s 1s/step - loss: 1.5885 - accuracy: 0.5508 - val_loss: 1.3282 - val_accuracy: 0.5211
# Epoch 32/100
# 12/12 [==============================] - 16s 1s/step - loss: 1.2127 - accuracy: 0.6158 - val_loss: 1.2318 - val_accuracy: 0.6105
# Epoch 33/100
# 12/12 [==============================] - 16s 1s/step - loss: 1.2581 - accuracy: 0.6158 - val_loss: 1.0536 - val_accuracy: 0.6842
# Epoch 34/100
# 12/12 [==============================] - 16s 1s/step - loss: 1.1489 - accuracy: 0.6525 - val_loss: 1.1107 - val_accuracy: 0.7000
# Epoch 35/100
# 12/12 [==============================] - 16s 1s/step - loss: 1.0767 - accuracy: 0.6977 - val_loss: 1.0474 - val_accuracy: 0.6737
# Epoch 36/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.9455 - accuracy: 0.6695 - val_loss: 0.9594 - val_accuracy: 0.7158
# Epoch 37/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.9873 - accuracy: 0.6780 - val_loss: 0.9233 - val_accuracy: 0.7263
# Epoch 38/100
# 12/12 [==============================] - 18s 2s/step - loss: 1.1622 - accuracy: 0.6525 - val_loss: 0.9215 - val_accuracy: 0.7526
# Epoch 39/100
# 12/12 [==============================] - 16s 1s/step - loss: 1.0539 - accuracy: 0.6695 - val_loss: 0.9541 - val_accuracy: 0.7211
# Epoch 40/100
# 12/12 [==============================] - 16s 1s/step - loss: 1.0421 - accuracy: 0.6751 - val_loss: 0.9836 - val_accuracy: 0.7263
# Epoch 41/100
# 12/12 [==============================] - 17s 1s/step - loss: 1.0599 - accuracy: 0.6638 - val_loss: 1.0526 - val_accuracy: 0.7211
# Epoch 42/100
# 12/12 [==============================] - 16s 1s/step - loss: 1.1034 - accuracy: 0.6384 - val_loss: 1.0639 - val_accuracy: 0.7789
# Epoch 43/100
# 12/12 [==============================] - 16s 1s/step - loss: 1.0299 - accuracy: 0.6751 - val_loss: 0.9089 - val_accuracy: 0.7579
# Epoch 44/100
# 12/12 [==============================] - 17s 1s/step - loss: 0.8171 - accuracy: 0.7316 - val_loss: 0.9173 - val_accuracy: 0.7263
# Epoch 45/100
# 12/12 [==============================] - 17s 1s/step - loss: 0.8504 - accuracy: 0.7203 - val_loss: 0.7887 - val_accuracy: 0.7684
# Epoch 46/100
# 12/12 [==============================] - 21s 2s/step - loss: 0.8439 - accuracy: 0.7627 - val_loss: 0.7936 - val_accuracy: 0.7842
# Epoch 47/100
# 12/12 [==============================] - 17s 1s/step - loss: 0.7113 - accuracy: 0.7684 - val_loss: 0.7218 - val_accuracy: 0.7895
# Epoch 48/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.8645 - accuracy: 0.7203 - val_loss: 0.9100 - val_accuracy: 0.7579
# Epoch 49/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.7864 - accuracy: 0.7260 - val_loss: 0.7174 - val_accuracy: 0.8053
# Epoch 50/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.7373 - accuracy: 0.7486 - val_loss: 0.9754 - val_accuracy: 0.7263
# Epoch 51/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.9444 - accuracy: 0.7147 - val_loss: 0.7390 - val_accuracy: 0.8053
# Epoch 52/100
# 12/12 [==============================] - 17s 1s/step - loss: 0.7787 - accuracy: 0.7627 - val_loss: 0.8034 - val_accuracy: 0.7842
# Epoch 53/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.7377 - accuracy: 0.7684 - val_loss: 0.9102 - val_accuracy: 0.7947
# Epoch 54/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.6768 - accuracy: 0.7458 - val_loss: 0.7075 - val_accuracy: 0.8474
# Epoch 55/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.6946 - accuracy: 0.7599 - val_loss: 0.7070 - val_accuracy: 0.8158
# Epoch 56/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.6488 - accuracy: 0.8192 - val_loss: 0.7513 - val_accuracy: 0.7895
# Epoch 57/100
# 12/12 [==============================] - 18s 1s/step - loss: 0.7055 - accuracy: 0.7684 - val_loss: 0.8353 - val_accuracy: 0.7737
# Epoch 58/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.6136 - accuracy: 0.8192 - val_loss: 0.7195 - val_accuracy: 0.8000
# Epoch 59/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.6558 - accuracy: 0.7966 - val_loss: 0.6447 - val_accuracy: 0.8316
# Epoch 60/100
# 12/12 [==============================] - 17s 1s/step - loss: 0.6856 - accuracy: 0.7655 - val_loss: 0.7700 - val_accuracy: 0.8263
# Epoch 61/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.6814 - accuracy: 0.7881 - val_loss: 0.6572 - val_accuracy: 0.8421
# Epoch 62/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.6959 - accuracy: 0.7825 - val_loss: 0.7066 - val_accuracy: 0.8263
# Epoch 63/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.6398 - accuracy: 0.8023 - val_loss: 0.6953 - val_accuracy: 0.8158
# Epoch 64/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.7401 - accuracy: 0.7768 - val_loss: 0.7943 - val_accuracy: 0.8053
# Epoch 65/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.6780 - accuracy: 0.7853 - val_loss: 0.7126 - val_accuracy: 0.8368
# Epoch 66/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.7447 - accuracy: 0.7797 - val_loss: 0.7417 - val_accuracy: 0.8053
# Epoch 67/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.6492 - accuracy: 0.7881 - val_loss: 0.8667 - val_accuracy: 0.7842
# Epoch 68/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.7512 - accuracy: 0.7627 - val_loss: 0.6812 - val_accuracy: 0.7842
# Epoch 69/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.6389 - accuracy: 0.8023 - val_loss: 0.7185 - val_accuracy: 0.8105
# Epoch 70/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.5420 - accuracy: 0.8220 - val_loss: 0.6116 - val_accuracy: 0.8526
# Epoch 71/100
# 12/12 [==============================] - 18s 1s/step - loss: 0.5048 - accuracy: 0.8475 - val_loss: 0.5301 - val_accuracy: 0.8947
# Epoch 72/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.5574 - accuracy: 0.8192 - val_loss: 0.5264 - val_accuracy: 0.8895
# Epoch 73/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.5285 - accuracy: 0.8475 - val_loss: 0.5972 - val_accuracy: 0.8789
# Epoch 74/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.5465 - accuracy: 0.8192 - val_loss: 0.5530 - val_accuracy: 0.8632
# Epoch 75/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.6005 - accuracy: 0.8051 - val_loss: 0.5683 - val_accuracy: 0.8737
# Epoch 76/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.4707 - accuracy: 0.8644 - val_loss: 0.5780 - val_accuracy: 0.8579
# Epoch 77/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.5803 - accuracy: 0.8418 - val_loss: 0.6838 - val_accuracy: 0.8737
# Epoch 78/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.5576 - accuracy: 0.8136 - val_loss: 0.5183 - val_accuracy: 0.8737
# Epoch 79/100
# 12/12 [==============================] - 17s 1s/step - loss: 0.4516 - accuracy: 0.8701 - val_loss: 0.5614 - val_accuracy: 0.8842
# Epoch 80/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.4986 - accuracy: 0.8390 - val_loss: 0.5737 - val_accuracy: 0.9000
# Epoch 81/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.5128 - accuracy: 0.8503 - val_loss: 0.5561 - val_accuracy: 0.8789
# Epoch 82/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.4982 - accuracy: 0.8588 - val_loss: 0.5278 - val_accuracy: 0.8947
# Epoch 83/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.3618 - accuracy: 0.8785 - val_loss: 0.5869 - val_accuracy: 0.8895
# Epoch 84/100
# 12/12 [==============================] - 18s 1s/step - loss: 0.4647 - accuracy: 0.8672 - val_loss: 0.5958 - val_accuracy: 0.8947
# Epoch 85/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.4747 - accuracy: 0.8588 - val_loss: 0.5587 - val_accuracy: 0.9000
# Epoch 86/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.4603 - accuracy: 0.8672 - val_loss: 0.5939 - val_accuracy: 0.8895
# Epoch 87/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.3789 - accuracy: 0.8983 - val_loss: 0.6494 - val_accuracy: 0.9053
# Epoch 88/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.3630 - accuracy: 0.9040 - val_loss: 0.4502 - val_accuracy: 0.9316
# Epoch 89/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.4921 - accuracy: 0.8446 - val_loss: 0.4691 - val_accuracy: 0.9053
# Epoch 90/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.3335 - accuracy: 0.9011 - val_loss: 0.5209 - val_accuracy: 0.9105
# Epoch 91/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.4014 - accuracy: 0.8672 - val_loss: 0.4234 - val_accuracy: 0.9263
# Epoch 92/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.4136 - accuracy: 0.8701 - val_loss: 0.4105 - val_accuracy: 0.9368
# Epoch 93/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.3361 - accuracy: 0.8870 - val_loss: 0.4171 - val_accuracy: 0.9263
# Epoch 94/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.3240 - accuracy: 0.9011 - val_loss: 0.4676 - val_accuracy: 0.9316
# Epoch 95/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.4249 - accuracy: 0.8757 - val_loss: 0.5574 - val_accuracy: 0.8947
# Epoch 96/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.4108 - accuracy: 0.8531 - val_loss: 0.4893 - val_accuracy: 0.9000
# Epoch 97/100
# 12/12 [==============================] - 17s 1s/step - loss: 0.3771 - accuracy: 0.8927 - val_loss: 0.5340 - val_accuracy: 0.9211
# Epoch 98/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.4794 - accuracy: 0.8559 - val_loss: 0.6314 - val_accuracy: 0.8947
# Epoch 99/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.5476 - accuracy: 0.8644 - val_loss: 0.5874 - val_accuracy: 0.8684
# Epoch 100/100
# 12/12 [==============================] - 16s 1s/step - loss: 0.6297 - accuracy: 0.8136 - val_loss: 0.5859 - val_accuracy: 0.8737

# %%
model.save('/content/drive/MyDrive/Colab Notebooks/BTVN/Rice/Nhan_dang_gao.h5')

# %%
model_gao = load_model('/content/drive/MyDrive/Colab Notebooks/BTVN/Rice/Nhan_dang_gao.h5')

# %%
Score=model.evaluate(train_set,verbose=0)
print('Train Loss', Score[0])
print('Train Accuracy', Score[1])
# Out:
# Train Loss 0.34990617632865906
# Train Accuracy 0.9180790781974792

# %%
test='/content/drive/MyDrive/Colab Notebooks/BT/nhan dien gao/Validation'
for i in os.listdir(test):
  img=load_img(test+'/'+i,target_size=(300,300))
  plt.imshow(img)
  img=img_to_array(img)
  img=img.astype('float32')
  img=img/255
  img=np.expand_dims(img,axis=0)
  result=model_gao.predict(img)
  if round(result[0][0])==1:
    prediction='Gao 4900'
  if round(result[0][1])==1:
    prediction = 'Gao 504'
  if round(result[0][2])==1:
    prediction='Gao 5451'
  if round(result[0][3])==1:
    prediction='Gao 6976'
  if round(result[0][4])==1:
    prediction = 'Gao ST21'
  if round(result[0][5])==1:
    prediction='Gao ST25'
  if round(result[0][6])==1:
    prediction='Gao bac huong'
  if round(result[0][7])==1:
    prediction = 'Gao den'
  if round(result[0][8])==1:
    prediction='Gao ham chau'
  if round(result[0][9])==1:
    prediction='Gao lut'
  if round(result[0][10])==1:
    prediction = 'Gao nang hoa'
  if round(result[0][11])==1:
    prediction='Gao nang sen'
  if round(result[0][12])==1:
    prediction='Gao nep'
  if round(result[0][13])==1:
    prediction = 'Gao tai nguyen'
  if round(result[0][14])==1:
    prediction='Gao thom'
  if round(result[0][15])==1:
    prediction='Gao thom lai'
  if round(result[0][16])==1:
    prediction = 'Gao tim than'
  if round(result[0][17])==1:
    prediction='Gao vang'
  print(prediction)
  plt.show()
# Out:
# 1/1 [==============================] - 1s 571ms/step
# Gao nang sen
# 1/1 [==============================] - 0s 17ms/step
# Gao nang hoa
# 1/1 [==============================] - 0s 17ms/step
# Gao ST21
# 1/1 [==============================] - 0s 16ms/step
# Gao tai nguyen
